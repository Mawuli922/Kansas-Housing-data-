# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
file_name='https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/FinalModule_Coursera/data/kc_house_data_NaN.csv'
df=pd.read_csv(file_name)

# %%
df.head()
# Out:
#    Unnamed: 0          id             date     price  bedrooms  bathrooms  \
# 0           0  7129300520  20141013T000000  221900.0       3.0       1.00
# 1           1  6414100192  20141209T000000  538000.0       3.0       2.25
# 2           2  5631500400  20150225T000000  180000.0       2.0       1.00
# 3           3  2487200875  20141209T000000  604000.0       4.0       3.00
# 4           4  1954400510  20150218T000000  510000.0       3.0       2.00
#
#    sqft_living  sqft_lot  floors  waterfront  ...  grade  sqft_above  \
# 0         1180      5650     1.0           0  ...      7        1180
# 1         2570      7242     2.0           0  ...      7        2170
# 2          770     10000     1.0           0  ...      6         770
# 3         1960      5000     1.0           0  ...      7        1050
# 4         1680      8080     1.0           0  ...      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
df.corr()
# Out:
#                Unnamed: 0        id     price  bedrooms  bathrooms  \
# Unnamed: 0       1.000000  0.006718  0.027372  0.010308   0.107013
# id               0.006718  1.000000 -0.016762  0.001332   0.005234
# price            0.027372 -0.016762  1.000000  0.308890   0.525885
# bedrooms         0.010308  0.001332  0.308890  1.000000   0.514508
# bathrooms        0.107013  0.005234  0.525885  0.514508   1.000000
# sqft_living      0.044717 -0.012258  0.702035  0.578405   0.755789
# sqft_lot        -0.026877 -0.132109  0.089661  0.032325   0.087932
# floors           0.179138  0.018525  0.256794  0.178178   0.502462
# waterfront      -0.007611 -0.002721  0.266369 -0.006800   0.063744
# view            -0.013751  0.011592  0.397293  0.080079   0.188390
# condition       -0.095419 -0.023783  0.036362  0.026704  -0.126263
# grade            0.082050  0.008130  0.667434  0.357145   0.665887
# sqft_above       0.071958 -0.010842  0.605567  0.479593   0.686735
# ...

# %%
df.drop(['Unnamed: 0','id'], axis = 1, inplace = True)

# %%
df.describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.161300e+04  21600.000000  21603.000000  21613.000000  2.161300e+04
# mean   5.400881e+05      3.372870      2.115736   2079.899736  1.510697e+04
# std    3.671272e+05      0.926657      0.768996    918.440897  4.142051e+04
# min    7.500000e+04      1.000000      0.500000    290.000000  5.200000e+02
# 25%    3.219500e+05      3.000000      1.750000   1427.000000  5.040000e+03
# 50%    4.500000e+05      3.000000      2.250000   1910.000000  7.618000e+03
# 75%    6.450000e+05      4.000000      2.500000   2550.000000  1.068800e+04
# max    7.700000e+06     33.000000      8.000000  13540.000000  1.651359e+06
#
#              floors    waterfront          view     condition         grade  \
# count  21613.000000  21613.000000  21613.000000  21613.000000  21613.000000
# mean       1.494309      0.007542      0.234303      3.409430      7.656873
# ...

# %%
df.corr()
# Out:
#                   price  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# price          1.000000  0.308890   0.525885     0.702035  0.089661  0.256794
# bedrooms       0.308890  1.000000   0.514508     0.578405  0.032325  0.178178
# bathrooms      0.525885  0.514508   1.000000     0.755789  0.087932  0.502462
# sqft_living    0.702035  0.578405   0.755789     1.000000  0.172826  0.353949
# sqft_lot       0.089661  0.032325   0.087932     0.172826  1.000000 -0.005201
# floors         0.256794  0.178178   0.502462     0.353949 -0.005201  1.000000
# waterfront     0.266369 -0.006800   0.063744     0.103818  0.021604  0.023698
# view           0.397293  0.080079   0.188390     0.284611  0.074710  0.029444
# condition      0.036362  0.026704  -0.126263    -0.058753 -0.008958 -0.263768
# grade          0.667434  0.357145   0.665887     0.762704  0.113621  0.458183
# sqft_above     0.605567  0.479593   0.686735     0.876597  0.183512  0.523885
# ...

# %%
sns.regplot(x="bathrooms",y="price", data = df)
# Out:
# <AxesSubplot:xlabel='bathrooms', ylabel='price'>

# %%
bins = np.linspace(min(df["sqft_living"]), max(df["sqft_living"]),4)
group_naming= ['Low','Medium','High']
df["sqft_living_binned"] = pd.cut(df["sqft_living"], bins, labels = group_naming, include_lowest = True)

# %%
df[["sqft_living","sqft_living_binned"]].head(15)
# Out:
#     sqft_living sqft_living_binned
# 0          1180                Low
# 1          2570                Low
# 2           770                Low
# 3          1960                Low
# 4          1680                Low
# 5          5420             Medium
# 6          1715                Low
# 7          1060                Low
# 8          1780                Low
# 9          1890                Low
# 10         3560                Low
# 11         1160                Low
# 12         1430                Low
# 13         1370                Low
# 14         1810                Low

# %%
df["sqft_living_binned"].value_counts()
# Out:
# Low       21331
# Medium      276
# High          6
# Name: sqft_living_binned, dtype: int64

# %%
sns.boxplot(x = "sqft_living_binned", y = "price", data = df).set_title("Visualization of the price distribution of homes in Kansas according to ranking")
# Out:
# Text(0.5, 1.0, 'Visualization of the price distribution of homes in Kansas according to ranking')

# %%
sns.histplot( df["price"])
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>

# %%
sns.histplot(df["sqft_living"]).set_title("Histogram of square ft per house in Kansas")
# Out:
# Text(0.5, 1.0, 'Histogram of square ft per house in Kansas')

# %%
df["bedrooms"].value_counts()
# Out:
# 3.0     9824
# 4.0     6882
# 2.0     2760
# 5.0     1601
# 6.0      272
# 1.0      199
# 7.0       38
# 8.0       13
# 9.0        6
# 10.0       3
# 11.0       1
# 33.0       1
# Name: bedrooms, dtype: int64

# %% [markdown]
# The value counts of bedrooms per house in Kansas reveals anomalies such as One 33 bedroom home, an 11 bedroom home, 3 10 bedroom homes and so on. In this project, the interest is in 4-bedroom homes and below, to determine pricing metrics and distribution. In order to avoid the influence of outliers, a dataframe was created out of the original dataframe, to contain data on pricing of homes with our desired criteria.

# %%
df_1 = df[df["bedrooms"]<5]

# %%
sns.histplot(df_1["price"]).set_title("histogram of prices of homes with 4 bedrooms or less in Kansas")
# Out:
# Text(0.5, 1.0, 'histogram of prices of homes with 4 bedrooms or less in Kansas')

# %%
df_1["price"].mean()
# Out:
# 514834.5030765319

# %%
df_1[["price","bedrooms","bathrooms"]].groupby(["bedrooms","bathrooms"]).count()
# Out:
#                     price
# bedrooms bathrooms
# 1.0      0.50           1
#          0.75          27
#          1.00         138
#          1.25           2
#          1.50          12
#          1.75           4
#          2.00           6
#          2.25           4
#          2.50           2
# 2.0      0.50           2
#          0.75          26
#          1.00        1558
#          1.25           3
#          1.50         294
#          1.75         304
#          2.00         216
#          2.25         118
#          2.50         197
#          2.75          20
#          3.00          13
#          3.25           8
#          3.50           1
# 3.0      0.75          16
#          1.00        1780
#          1.25           4
#          1.50         829
#          1.75        1870
#          2.00        1048
#          2.25        1082
#          2.50        2357
#          2.75         275
#          3.00         197
#          3.25         184
# ...

# %% [markdown]
# The dataframe above shows a count of 4-bedroom and below homes in Kansas depending on the number of rooms and bathrooms. In the code below, we obtain the average pricing per home based on the same metrics. This provides better insights in contrast to just calculating the average price in general. Using the information below in tandem with the information above is beneficial. For example, Investors can tell that 4 bed, 2.5 bath homes sold the most, with an average sale price of \\$580K, while 3 bed, 2.5 bath has the next highest sales with average price of  \\$520k

# %%
df_1[["price","bedrooms","bathrooms"]].groupby(["bedrooms","bathrooms"]).mean()
# Out:
#                            price
# bedrooms bathrooms
# 1.0      0.50       2.550000e+05
#          0.75       2.510537e+05
#          1.00       3.166300e+05
#          1.25       8.817500e+05
#          1.50       3.257458e+05
#          1.75       3.660500e+05
#          2.00       2.971667e+05
#          2.25       4.362250e+05
#          2.50       4.895000e+05
# 2.0      0.50       1.910000e+05
#          0.75       3.275135e+05
#          1.00       3.480728e+05
#          1.25       4.689833e+05
#          1.50       4.101214e+05
#          1.75       4.712487e+05
#          2.00       4.483562e+05
#          2.25       5.176548e+05
#          2.50       5.408968e+05
#          2.75       5.509421e+05
#          3.00       6.445885e+05
#          3.25       8.666500e+05
#          3.50       5.350000e+05
# 3.0      0.75       3.115126e+05
#          1.00       3.361846e+05
#          1.25       6.051250e+05
#          1.50       3.981893e+05
# ...

# %%
sns.histplot(df_1["bathrooms"]).set_title("histogram of number of bathrooms per house for houses with 4 bedrooms and below in Kansas")
# Out:
# Text(0.5, 1.0, 'histogram of number of bathrooms per house for houses with 4 bedrooms and below in Kansas')

# %%
sns.heatmap(df_1.corr())
# Out:
# <AxesSubplot:>

# %%
df_1[["bathrooms","bedrooms","sqft_living","price"]].corr()
# Out:
#              bathrooms  bedrooms  sqft_living     price
# bathrooms     1.000000  0.491152     0.727308  0.491417
# bedrooms      0.491152  1.000000     0.563003  0.277212
# sqft_living   0.727308  0.563003     1.000000  0.679795
# price         0.491417  0.277212     0.679795  1.000000

# %% [markdown]
# sqft_living has the highest correlation to price. The relationship between sqft_living and price will be further investigated.

# %%
sns.regplot(x= "sqft_living",y="price", data = df)
# Out:
# <AxesSubplot:xlabel='sqft_living', ylabel='price'>

# %%
sns.residplot(x = "sqft_living", y = "price", data = df).set_title("Plot of Residuals of Price against Living sq. ft linear regression")
# Out:
# Text(0.5, 1.0, 'Plot of Residuals of Price against Living sq. ft linear regression')

# %% [markdown]
# The variance of the residuals is increasing and as such, a linear model is not the best fit to describe the relationship between the two variables.

# %% [markdown]
# Determining the appropriate regression function for the prediction of prices based on Living sq. ft in Kansas

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split

# %%
lr = LinearRegression()

# %%
y_data = df_1[["price"]]
x_data = df_1[["sqft_living"]]

# %%
x_train,x_test,y_train,y_test = train_test_split(x_data, y_data, test_size = 0.2, random_state = 0)

# %%
test_stat = []
degree_poly = [1,2,3,4]
for n in degree_poly:
    pr = PolynomialFeatures(degree=n)
    x_train1 = pr.fit_transform(x_train)
    x_test1 = pr.fit_transform(x_test)
    lr.fit(x_train1, y_train)
    test_stat.append(lr.score(x_test1,y_test))

# %%
test_stat
# Out:
# [0.4445041299227248,
#  0.4840667903132807,
#  0.4840328597915723,
#  0.48693619834145574]

# %% [markdown]
# from the list of R squared scores, degree 4 polynomial seems to have the highest score however the discrepancy between 2,3,4 is very minute and as such a compromise to avoid overfitting leads to selection of degree 3 polynomial for our linear model

# %%
pr = PolynomialFeatures(degree = 3)

# %%
x_train3 = pr.fit_transform(x_train)
x_test3 = pr.fit_transform(x_test)
lr.fit(x_train3,y_train)
yhat_test = lr.predict(x_test3)
yhat_train = lr.predict(x_train3)

# %%
plt.figure(figsize = (12,8))
plt.title("Comparison of Density Distribution of Training and Test predictions against the Actual data")
sns.distplot(y_data, hist = False, color = 'r', label = "Actual Data")
sns.distplot(yhat_test, hist = False, color = 'b', label = "Test predictions")
sns.distplot(yhat_train, hist = False, color = 'g', label = "Training predictions")
plt.legend()
plt.xlabel("Kansas Housing Prices (US$)")
# Out:
# C:\Users\mawul\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\mawul\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# The presence of outliers within the dataset causes the distribution to be skewed left to reflect the true mean.
